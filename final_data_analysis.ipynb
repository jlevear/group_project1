# %%
# Import dependancies and locate/read csv file
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde

happiness_file = 'Resources/happiness_years.csv'
top_10_file = 'Resources/happiness_top_10.csv'
bottom_10_file = 'Resources/happiness_bottom_10.csv'
top_bottom_10_file = 'Resources/happiness_top_bottom_10.csv'
region_avgs_file = 'Resources/happiness_region_avgs.csv'
us_file = 'Resources/happiness_us.csv'
merge_file = 'Resources/countries_happiness_merge.csv'

happiness_df = pd.read_csv(happiness_file)
top_10_df = pd.read_csv(top_10_file)
bottom_10_df = pd.read_csv(bottom_10_file)
top_bottom_10_df = pd.read_csv(top_bottom_10_file)
region_avgs_df = pd.read_csv(region_avgs_file)
us_df = pd.read_csv(us_file)
merge_df = pd.read_csv(merge_file)

# %%
# Happiness score vs GDP 
x_axis1 = happiness_df['Happiness Rank']
y_axis1 = happiness_df['Economy (GDP per Capita)']

x_axis2 = top_bottom_10_df['Happiness Rank']
y_axis2 = top_bottom_10_df['Economy (GDP per Capita)']

x_axis3 = us_df['Happiness Rank']
y_axis3 = us_df['Economy (GDP per Capita)']

plt.figure(figsize=(12,6))

# (code from url: 
# https://stackoverflow.com/questions/20105364/how-can-i-make-a-scatter-plot-colored-by-density-in-matplotlib)
# (User: Joe Kington)
xy = np.vstack([x_axis1,y_axis1])
z = gaussian_kde(xy)(xy)

plt.scatter(x_axis1, y_axis1, c=z, s=50, edgecolor='')

plt.scatter(x_axis2, y_axis2, marker='o', facecolors='tab:blue', edgecolors='red', alpha=0.75)

plt.scatter(x_axis3, y_axis3, marker='*', facecolors='black', s=100)

plt.ylabel('Economy (GDP per Capita)')
plt.xlabel('Happiness Rank')
plt.title('Country GDP per Capita by Happiness Rank 2015-2019')
plt.grid(b=True)
plt.gca().invert_xaxis()

print(happiness_df[['Happiness Rank','Economy (GDP per Capita)']].corr())

plt.savefig('Images/Country GDP per Capita by Happiness Rank 2015-2019.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                           Happiness Rank  Economy (GDP per Capita)
# Happiness Rank                  1.000000                 -0.794791
# Economy (GDP per Capita)       -0.794791                  1.000000

# %%
x_axis1 = happiness_df['Happiness Rank']
y_axis1 = happiness_df['Social Support']

x_axis2 = top_bottom_10_df['Happiness Rank']
y_axis2 = top_bottom_10_df['Social Support']

x_axis3 = us_df['Happiness Rank']
y_axis3 = us_df['Social Support']

xy = np.vstack([x_axis1,y_axis1])

z = gaussian_kde(xy)(xy)

plt.figure(figsize=(12,6))

plt.scatter(x_axis1, y_axis1, c=z, s=50, edgecolor='')

plt.scatter(x_axis2, y_axis2, marker='o', facecolors='tab:blue', edgecolors='red', alpha=0.75)

plt.scatter(x_axis3, y_axis3, marker='*', facecolors='black', s=100)

plt.ylabel('Social Support')
plt.xlabel('Happiness Rank')
plt.title('Country Social Support by Happiness Rank 2015-2019')
plt.grid(b=True)
plt.gca().invert_xaxis()

print(happiness_df[['Happiness Rank','Social Support']].corr())

plt.savefig('Images/Country Social Support by Happiness Rank 2015-2019.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                 Happiness Rank  Social Support
# Happiness Rank        1.000000       -0.644842
# Social Support       -0.644842        1.000000

# %%
x_axis1 = happiness_df['Happiness Rank']
y_axis1 = happiness_df['Health (Life Expectancy)']

x_axis2 = top_bottom_10_df['Happiness Rank']
y_axis2 = top_bottom_10_df['Health (Life Expectancy)']

x_axis3 = us_df['Happiness Rank']
y_axis3 = us_df['Health (Life Expectancy)']

xy = np.vstack([x_axis1,y_axis1])

z = gaussian_kde(xy)(xy)

plt.figure(figsize=(12,6))

plt.scatter(x_axis1, y_axis1, c=z, s=50, edgecolor='')

plt.scatter(x_axis2, y_axis2, marker='o', facecolors='tab:blue', edgecolors='red', alpha=0.75)

plt.scatter(x_axis3, y_axis3, marker='*', facecolors='black', s=100)

plt.ylabel('Health (Life Expectancy)')
plt.xlabel('Happiness Rank')
plt.title('Country Life Expectancy by Happiness Rank 2015-2019')
plt.grid(b=True)
plt.gca().invert_xaxis()

print(happiness_df[['Happiness Rank','Health (Life Expectancy)']].corr())

plt.savefig('Images/Country Life Expectancy by Happiness Rank 2015-2019.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                           Happiness Rank  Health (Life Expectancy)
# Happiness Rank                  1.000000                 -0.743655
# Health (Life Expectancy)       -0.743655                  1.000000

# %%
x_axis1 = happiness_df['Happiness Rank']
y_axis1 = happiness_df['Freedom']

x_axis2 = top_bottom_10_df['Happiness Rank']
y_axis2 = top_bottom_10_df['Freedom']

x_axis3 = us_df['Happiness Rank']
y_axis3 = us_df['Freedom']

xy = np.vstack([x_axis1,y_axis1])

z = gaussian_kde(xy)(xy)

plt.figure(figsize=(12,6))

plt.scatter(x_axis1, y_axis1, c=z, s=50, edgecolor='')

plt.scatter(x_axis2, y_axis2, marker='o', facecolors='tab:blue', edgecolors='red', alpha=0.75)

plt.scatter(x_axis3, y_axis3, marker='*', facecolors='black', s=100)

plt.ylabel('Freedom')
plt.xlabel('Happiness Rank')
plt.title('Country Freedom by Happiness Rank 2015-2019')
plt.grid(b=True)
plt.gca().invert_xaxis()

print(happiness_df[['Happiness Rank','Freedom']].corr())

plt.savefig('Images/Country Freedom by Happiness Rank 2015-2019', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                 Happiness Rank   Freedom
# Happiness Rank        1.000000 -0.537942
# Freedom              -0.537942  1.000000

# %%
x_axis1 = happiness_df['Happiness Rank']
y_axis1 = happiness_df['Generosity']

x_axis2 = top_bottom_10_df['Happiness Rank']
y_axis2 = top_bottom_10_df['Generosity']

x_axis3 = us_df['Happiness Rank']
y_axis3 = us_df['Generosity']

xy = np.vstack([x_axis1,y_axis1])

z = gaussian_kde(xy)(xy)

plt.figure(figsize=(12,6))

plt.scatter(x_axis1, y_axis1, c=z, s=50, edgecolor='')

plt.scatter(x_axis2, y_axis2, marker='o', facecolors='tab:blue', edgecolors='red', alpha=0.75)

plt.scatter(x_axis3, y_axis3, marker='*', facecolors='black', s=100)

plt.ylabel('Generosity')
plt.xlabel('Happiness Rank')
plt.title('Country Generosity by Happiness Rank 2015-2019')
plt.grid(b=True)
plt.gca().invert_xaxis()

print(happiness_df[['Happiness Rank','Generosity']].corr())

plt.savefig('Images/Country Generosity by Happiness Rank 2015-2019.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                 Happiness Rank  Generosity
# Happiness Rank        1.000000   -0.117713
# Generosity           -0.117713    1.000000

# %%
sorted_regions = region_avgs_df.sort_values(by=['Generosity'])
sorted_regions

x = sorted_regions['Region']
y = sorted_regions['Generosity']

xy = np.vstack([x,y])

plt.figure(figsize=(12,6))

plt.barh(x, y)

plt.ylabel('Region')
plt.xlabel('Avg Generosity')
plt.title('Region Avg Generosity')

plt.savefig('Images/Region Avg Generosity.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
regroup_country = merge_df.groupby(["Country"])
regroup_country

# %%
us = regroup_country.groups["United States"]
us = regroup_country.get_group("United States")
us
# Out:
#      Unnamed: 0        Country  Population (millions)   HDI GDP per Capita  \
# 131         131  United States                  317.5  0.91     $49,725.00
#
#      Total Ecological Footprint  Total Biocapacity  \
# 131                        8.22               3.76
#
#      Biocapacity Deficit or Reserve  Earths Required  Countries Required  \
# 131                           -4.46             4.75                2.19
#
#           Region_y  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 131  North America              13            7.104                   1.50796
#
#       Family  Health (Life Expectancy)  Freedom  \
# 131  1.04782                     0.779  0.48163
#
#      Trust (Government Corruption)  Generosity
# 131                        0.14868     0.41077

# %%
# where is the US? happiness rank and biocapacity deficit/reserve
x_axis1 = us['Happiness Rank']
y_axis1 = us['Biocapacity Deficit or Reserve']

x_axis2 = merge_df['Happiness Rank']
y_axis2 = merge_df['Biocapacity Deficit or Reserve']

plt.figure(figsize=(12,6))

# (code from url: 
# https://stackoverflow.com/questions/20105364/how-can-i-make-a-scatter-plot-colored-by-density-in-matplotlib)
# (User: Joe Kington)
xy = np.vstack([x_axis2,y_axis2])
z = gaussian_kde(xy)(xy)

plt.scatter(x_axis2, y_axis2, c=z, s=100, edgecolor='')

plt.scatter(x_axis1, y_axis1, marker='*', facecolors='tab:red', s=300, alpha=0.75)

plt.ylabel('Biocapacity Deficit or Reserve')
plt.xlabel('Happiness Rank')
plt.title('Country Biocapacity Deficit or Reserve by Happiness Rank 2016')
plt.grid(b=True)
plt.gca().invert_xaxis()
plt.ylim(top=3, bottom=-5)

print(merge_df[['Happiness Rank','Biocapacity Deficit or Reserve']].corr())

plt.savefig('Images/Country Biocapacity Deficit or Reserve by Happiness Rank 2016.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                                 Happiness Rank  Biocapacity Deficit or Reserve
# Happiness Rank                        1.000000                        0.014911
# Biocapacity Deficit or Reserve        0.014911                        1.000000

# %%
# where is the US? happiness rank and biocapacity deficit/reserve
x_axis1 = us['Happiness Rank']
y_axis1 = us['Total Ecological Footprint']

x_axis2 = merge_df['Happiness Rank']
y_axis2 = merge_df['Total Ecological Footprint']

plt.figure(figsize=(12,6))

# (code from url: 
# https://stackoverflow.com/questions/20105364/how-can-i-make-a-scatter-plot-colored-by-density-in-matplotlib)
# (User: Joe Kington)
xy = np.vstack([x_axis2,y_axis2])
z = gaussian_kde(xy)(xy)

plt.scatter(x_axis2, y_axis2, c=z, s=100, edgecolor='')

plt.scatter(x_axis1, y_axis1, marker='*', facecolors='tab:red', s=300, alpha=0.75)

plt.ylabel('Total Ecological Footprint')
plt.xlabel('Happiness Rank')
plt.title('Country Total Ecological Footprint vs Happiness Rank 2016')
plt.grid(b=True)
plt.gca().invert_xaxis()

print(merge_df[['Happiness Rank','Total Ecological Footprint']].corr())

plt.savefig('Images/Country Total Ecological Footprint vs Happiness Rank 2016.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                             Happiness Rank  Total Ecological Footprint
# Happiness Rank                    1.000000                   -0.674515
# Total Ecological Footprint       -0.674515                    1.000000
